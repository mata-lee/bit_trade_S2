# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd ../gdrive
# Out:
# /gdrive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
cd Shareddrives/mata/개인/공모전/Dacon_비트트레이더_S2/data
# 공유폴더 파일 내 알집 파일 풀기
# !unzip -qq 'open.zip'
cd ../
# Out:
# /gdrive/Shareddrives/mata/개인/공모전/Dacon_비트트레이더_S2

# %%
base_path = os.getcwd()
data_path = os.path.join(base_path, 'data')

# %%
train_x_df = pd.read_csv(os.path.join(data_path, 'train_x_df.csv'))
train_y_df = pd.read_csv(os.path.join(data_path, 'train_y_df.csv'))
test_x_df = pd.read_csv(os.path.join(data_path, 'test_x_df.csv'))

# %%
train_x_df.head()
# Out:
#    sample_id  time  coin_index  ...    trades  tb_base_av  tb_quote_av
# 0          0     0           9  ...  0.009855    0.000848     6.771755
# 1          0     1           9  ...  0.016137    0.000697     5.565188
# 2          0     2           9  ...  0.014166    0.000905     7.225459
# 3          0     3           9  ...  0.021557    0.001171     9.353000
# 4          0     4           9  ...  0.021434    0.001799    14.372534
#
# [5 rows x 12 columns]

# %%
train_y_df.head()
# Out:
#    sample_id  time  coin_index  ...    trades  tb_base_av  tb_quote_av
# 0          0     0           9  ...  0.012565    0.000605     4.904978
# 1          0     1           9  ...  0.020572    0.003014    24.453999
# 2          0     2           9  ...  0.016630    0.002967    24.069899
# 3          0     3           9  ...  0.019463    0.002362    19.158766
# 4          0     4           9  ...  0.030180    0.001533    12.421005
#
# [5 rows x 12 columns]

# %%
test_x_df.head()
# Out:
#    sample_id  time  coin_index  ...      trades    tb_base_av    tb_quote_av
# 0       7661     0           7  ...  553.533691   76317.68750   69457.835938
# 1       7661     1           7  ...  514.306885  291661.37500  265331.843750
# 2       7661     2           7  ...  361.758240  288066.12500  262389.562500
# 3       7661     3           7  ...  329.069244  113585.00000  103350.929688
# 4       7661     4           7  ...  481.617889   70405.78125   63988.847656
#
# [5 rows x 12 columns]

# %%
print(f'Shape of train_x: {train_x_df.shape}')
print(f'Shape of train_y: {train_y_df.shape}')
print(f'Shape of test_x: {test_x_df.shape}')
# Out:
# Shape of train_x: (10572180, 12)
# Shape of train_y: (919320, 12)
# Shape of test_x: (738300, 12)

# %%
train_x_df['sample_id'].nunique() # 7661
train_x_df['time'].nunique() # 1380
train_x_df['coin_index'].nunique() # 10
# Out:
# 1380

# %%
train_x_df[train_x_df.sample_id == 0]['open'].plot()

# %%
# GIthub push 용도
# !git init
# !git config --global user.email 'mata.lee@nexr.com'
# !git config --global user.name 'mata_lee'

# !git add .
# !git commit -m 'message'
# Out:
# Initialized empty Git repository in /gdrive/Shareddrives/mata/개인/공모전/Dacon_비트트레이더_S2/.git/

# %%
# Out:
# /bin/bash: vim: command not found
